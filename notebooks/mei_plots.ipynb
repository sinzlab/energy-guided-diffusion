# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle

plt.style.use("default")
sns.set_context("talk")

# %%
with open("./cross_activation.pkl", "rb") as f:
    data = pickle.load(f)

# %%
dm_val = [
    27.695505142211914,
    8.161521911621094,
    9.442479133605957,
    6.156960487365723,
    5.848766326904297,
    13.712553977966309,
    11.097506523132324,
    6.052864074707031,
    11.305069923400879,
    6.259583950042725,
    7.206928253173828,
    8.861069679260254,
    15.690559387207031,
    22.0837459564209,
    12.238764762878418,
    36.30913543701172,
    26.123676300048828,
    13.2135009765625,
    23.24651527404785,
    20.378318786621094,
    7.720729351043701,
    3.4483354091644287,
    8.051850318908691,
    11.247852325439453,
    11.458130836486816,
    7.051078796386719,
][3:]

dm_d_t1 = [
    8.38464641571045,
    5.382554054260254,
    4.794810771942139,
    2.498978853225708,
    4.357154846191406,
    4.0011491775512695,
    2.6805851459503174,
    1.0910310745239258,
    5.339254856109619,
    3.4918229579925537,
    4.113437175750732,
    2.3202202320098877,
    8.960630416870117,
    5.884815216064453,
    9.089123725891113,
    14.959891319274902,
    12.589820861816406,
    7.655852794647217,
    11.452397346496582,
    5.701546669006348,
    3.4327874183654785,
    2.5150222778320312,
    4.278099060058594,
    5.5336527824401855,
    6.878515720367432,
    4.112643718719482,
][3:]

# %%
data
# Out:
# {'d_d1': array([ 2.7377841,  3.0207238,  5.87967  ,  7.2133026,  5.469557 ,
#          7.8390994,  4.4867835,  5.9621425, 12.733504 , 22.798971 ,
#         25.860594 , 22.778715 , 32.6656   , 30.628942 , 16.274906 ,
#         15.913459 , 16.610922 , 15.929178 ,  1.6591126, 10.409044 ,
#          9.87192  ,  9.591734 , 11.015822 ], dtype=float32),
#  'd_d2': array([ 2.4282584,  2.791879 ,  5.0381174,  6.772957 ,  4.930513 ,
#          7.065686 ,  4.3638864,  6.1180725,  9.193487 , 18.209906 ,
#         21.673494 , 20.708227 , 28.392487 , 25.60851  , 13.201367 ,
#         12.721008 , 11.501536 , 13.468859 ,  1.7181901,  9.780336 ,
#          8.763432 ,  8.755553 , 10.027439 ], dtype=float32),
#  'd_t1': array([ 1.7750409 ,  2.8699138 ,  2.4470687 ,  2.404311  ,  1.4816743 ,
#          3.336886  ,  2.293538  ,  3.819002  ,  1.4176053 , 13.189147  ,
#         10.650681  , 17.030981  , 16.024412  , 14.614415  , 11.193942  ,
# ...

# %%
plt.figure(figsize=(8.75, 4), dpi=150, facecolor="w")
plt.subplot(1, 2, 1)
plt.plot([0, 40], [0, 40], c="tab:gray", ls="--", lw=2)
plt.plot(
    [0, 40], [0, 40 * (np.array(dm_val) / np.array(data["d_d2"])).mean()], c="k", lw=2
)
plt.scatter(data["d_d2"], dm_val, c="#1E88E5", zorder=10)
plt.axis("equal")
plt.xlim(0, 40)
plt.ylim(0, 40)
plt.xlabel("Gradient Ascent\n Validation DD Ensemble")
plt.ylabel("Energy Guided Diffusion\n Validation DD Ensemble")
plt.text(5, 34, f"$r(x) = {(np.array(dm_val) / np.array(data['d_d2'])).mean():.2f}x$")
plt.title(f"Data-Driven (DD)")

plt.subplot(1, 2, 2)
plt.plot([0, 40], [0, 40], c="tab:gray", ls="--", lw=2)
plt.plot(
    [0, 40], [0, 40 * (np.array(dm_d_t1) / np.array(data["d_t1"])).mean()], c="k", lw=2
)
plt.scatter(data["d_t1"], dm_d_t1, c="#EDAC32", zorder=10)
plt.axis("equal")
plt.xlim(0, 20)
plt.ylim(0, 20)
plt.xlabel("Gradient Ascent\n Validation TD Ensemble")
plt.ylabel("")
plt.text(4, 17, f"$r(x) = {(np.array(dm_d_t1) / np.array(data['d_t1'])).mean():.2f}x$")
plt.title(f"Task-Driven (TD)")

# plt.gca().set_yticklabels([])

sns.despine(trim=True)
# plt.savefig('./validation_comparison.png', bbox_inches='tight', dpi=150)
plt.show()

# %%
for i in range(75):
    image = np.load("../scripts/75_monkey_test_imgs.npy")[i]
    plt.imshow(image, cmap="gray")
    plt.axis("off")
    plt.margins(0, 0)
    plt.subplots_adjust(top=1, bottom=0, right=1, left=0, hspace=0, wspace=0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.title(i)
    plt.show()

# %%
import torch

torch.Tensor(image).norm()
# Out:
# tensor(88.8599)

# %%
plt.bar([0, 1], [25, 120])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.bar([0, 1], [25, 120])
#
# NameError: name 'plt' is not defined
